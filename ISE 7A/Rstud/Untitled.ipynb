# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np

# %%
df=pd.read_csv("Iris.csv")

# %%
df.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
# Id               150 non-null int64
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df["SepalLengthCm"].fillna(df["SepalLengthCm"].mean(),inplace=True)

# %%
df.head(100)
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0     1            5.1           3.5            1.4           0.2
# 1     2            4.9           3.0            1.4           0.2
# 2     3            4.7           3.2            1.3           0.2
# 3     4            4.6           3.1            1.5           0.2
# 4     5            5.0           3.6            1.4           0.2
# ..  ...            ...           ...            ...           ...
# 95   96            5.7           3.0            4.2           1.2
# 96   97            5.7           2.9            4.2           1.3
# 97   98            6.2           2.9            4.3           1.3
# 98   99            5.1           2.5            3.0           1.1
# 99  100            5.7           2.8            4.1           1.3
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 95  Iris-versicolor
# ...

# %%
df.sort_values("SepalLengthCm",inplace=True)

# %%
df.head(100)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 13    14            4.3           3.0            1.1           0.1
# 42    43            4.4           3.2            1.3           0.2
# 38    39            4.4           3.0            1.3           0.2
# 8      9            4.4           2.9            1.4           0.2
# 41    42            4.5           2.3            1.3           0.3
# ..   ...            ...           ...            ...           ...
# 68    69            6.2           2.2            4.5           1.5
# 97    98            6.2           2.9            4.3           1.3
# 148  149            6.2           3.4            5.4           2.3
# 126  127            6.2           2.8            4.8           1.8
# 72    73            6.3           2.5            4.9           1.5
#
#              Species
# 13       Iris-setosa
# 42       Iris-setosa
# 38       Iris-setosa
# 8        Iris-setosa
# 41       Iris-setosa
# ..               ...
# ...

# %%
df.drop_duplicates(subset="SepalLengthCm",keep=False,inplace=True)

# %%
df.head(100)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 13    14            4.3           3.0            1.1           0.1
# 41    42            4.5           2.3            1.3           0.3
# 48    49            5.3           3.7            1.5           0.2
# 50    51            7.0           3.2            4.7           1.4
# 102  103            7.1           3.0            5.9           2.1
# 107  108            7.3           2.9            6.3           1.8
# 130  131            7.4           2.8            6.1           1.9
# 105  106            7.6           3.0            6.6           2.1
# 131  132            7.9           3.8            6.4           2.0
#
#              Species
# 13       Iris-setosa
# 41       Iris-setosa
# 48       Iris-setosa
# 50   Iris-versicolor
# 102   Iris-virginica
# 107   Iris-virginica
# 130   Iris-virginica
# 105   Iris-virginica
# 131   Iris-virginica

# %%
df["Species"].value_counts()
# Out:
# Iris-virginica     5
# Iris-setosa        3
# Iris-versicolor    1
# Name: Species, dtype: int64

# %% [markdown]
# tmp=df.drop('id',axis=1)

# %%
tmp=df.drop('Id',axis=1)

# %%
g=sb.pairplot(tmp,hue='Species',markers='+')
# Out:
# /home/kumar/.local/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/kumar/.local/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/kumar/.local/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/kumar/.local/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
df.head(100)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 13    14            4.3           3.0            1.1           0.1
# 41    42            4.5           2.3            1.3           0.3
# 48    49            5.3           3.7            1.5           0.2
# 50    51            7.0           3.2            4.7           1.4
# 102  103            7.1           3.0            5.9           2.1
# 107  108            7.3           2.9            6.3           1.8
# 130  131            7.4           2.8            6.1           1.9
# 105  106            7.6           3.0            6.6           2.1
# 131  132            7.9           3.8            6.4           2.0
#
#              Species
# 13       Iris-setosa
# 41       Iris-setosa
# 48       Iris-setosa
# 50   Iris-versicolor
# 102   Iris-virginica
# 107   Iris-virginica
# 130   Iris-virginica
# 105   Iris-virginica
# 131   Iris-virginica

# %%
plt.show()
